# %% [markdown]
# <a href="https://colab.research.google.com/github/kikiru328/enterprise_analysis/blob/main/B_clf_total_amt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
my_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', my_path)
sys.path.insert(0,my_path)

# 한글폰트
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
## 돌리고 런타임 재시작
## 드라이브 마운트, 한글폰트설치코드 제외 셀 실행
# Out:
# Mounted at /content/drive
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (8,413 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
#  Directory 변경 (모듈이용)
# %pwd
# %cd '../content/notebooks'

# module import
## Data Load
from pickle5 import pickle 

## Basic module
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

#waring
import warnings
warnings.filterwarnings('ignore')
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/data/EDA/pr_1','rb') as f1:
  pr_1 = pickle.load(f1)
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/data/EDA/pr_2','rb') as f2:
  pr_2 = pickle.load(f2)
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/data/EDA/pr_3','rb') as f3:
  pr_3 = pickle.load(f3)
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/data/EDA/pr_4','rb') as f4:
  pr_4 = pickle.load(f4)

# %%
def setidx(df):
  df = df.reset_index()
  df = df.rename(columns={'index':'고객번호'})
  df = df.set_index('고객번호')
  return df

df_1 = setidx(pr_1)
df_2 = setidx(pr_2)
df_3 = setidx(pr_3)
df_4 = setidx(pr_4)

# %%
df_1
# Out:
#         가공식품  가구/인테리어  교육/문화용품  ...  전문스포츠/레저_구매금액  패션잡화_구매금액     총구매금액
# 고객번호                            ...
# 1       66.0      9.0      0.0  ...        2143200    1716860  19925355
# 2       48.0     31.0      0.0  ...        3949760     903320  24323230
# 3      237.0      0.0      0.0  ...              0          0    851215
# 4       90.0      7.0      0.0  ...         402100     771770   5042106
# 5      121.0     28.0      0.0  ...          63080     218570   5460150
# ...      ...      ...      ...  ...            ...        ...       ...
# 19356   29.0      0.0      0.0  ...              0          0    170160
# 19357    7.0      0.0      0.0  ...              0          0     91950
# 19359   11.0      0.0      0.0  ...              0          0     43190
# 19360   20.0      0.0      0.0  ...              0          0    368050
# 19364    9.0      0.0      0.0  ...         336900          0   2032420
#
# [19085 rows x 23 columns]

# %%
sorting_cols = pr_1.columns.to_list()
sorting_cols = ['가공식품_구매금액',
 '가구/인테리어_구매금액',
 '교육/문화용품_구매금액',
 '기타_구매금액',
 '디지털/가전_구매금액',
 '명품_구매금액',
 '신선식품_구매금액',
 '의류_구매금액',
 '일상용품_구매금액',
 '전문스포츠/레저_구매금액',
 '패션잡화_구매금액',
 '총구매금액']

# %%
def_cols = ['가공식품_구매금액','가구/인테리어_구매금액',
 '교육/문화용품_구매금액',
 '기타_구매금액',
 '디지털/가전_구매금액',
 '명품_구매금액',
 '신선식품_구매금액',
 '의류_구매금액',
 '일상용품_구매금액',
 '전문스포츠/레저_구매금액',
 '패션잡화_구매금액']

# %%
sum_cols = ['가공식품_구매금액_r', '가구/인테리어_구매금액_r', '교육/문화용품_구매금액_r',
       '기타_구매금액_r', '디지털/가전_구매금액_r', '명품_구매금액_r', '신선식품_구매금액_r', '의류_구매금액_r',
       '일상용품_구매금액_r', '전문스포츠/레저_구매금액_r', '패션잡화_구매금액_r']

# %%
confirm_cols = ['가공식품_구매금액_r', '가구/인테리어_구매금액_r', '교육/문화용품_구매금액_r',
       '기타_구매금액_r', '디지털/가전_구매금액_r', '명품_구매금액_r', '신선식품_구매금액_r', '의류_구매금액_r',
       '일상용품_구매금액_r', '전문스포츠/레저_구매금액_r', '패션잡화_구매금액_r', 'total']

# %%
p1 = df_1[sorting_cols]
p2 = df_2[sorting_cols]
p3 = df_3[sorting_cols]
p4 = df_4[sorting_cols]

# %%
p1
# Out:
#        가공식품_구매금액  가구/인테리어_구매금액  ...  패션잡화_구매금액     총구매금액
# 고객번호                            ...
# 1        3550030        696520  ...    1716860  19925355
# 2        1485380       1735160  ...     903320  24323230
# 3         530250             0  ...          0    851215
# 4         810700        125760  ...     771770   5042106
# 5        1325670        415330  ...     218570   5460150
# ...          ...           ...  ...        ...       ...
# 19356      87670             0  ...          0    170160
# 19357      29650             0  ...          0     91950
# 19359      12300             0  ...          0     43190
# 19360      83750             0  ...          0    368050
# 19364      58600             0  ...          0   2032420
#
# [19085 rows x 12 columns]

# %%
def reName(a,df):
  cols = list(df.columns)
  for i in cols:
    df[f'{i}_{a}'] = df[i]
  A = df.drop(cols,axis=1)
  return A

# %%
H1 = reName(1,p1)
H2 = reName(2,p2)
H3 = reName(3,p3)
H4 = reName(4,p4)

# %%
def new_train_df(a,b):
    A = pd.concat([a,b],axis=1)
    return A
train = new_train_df(H1,H2)

# %%
H1
# Out:
#        가공식품_구매금액_1  가구/인테리어_구매금액_1  ...  패션잡화_구매금액_1   총구매금액_1
# 고객번호                                ...
# 1          3550030          696520  ...      1716860  19925355
# 2          1485380         1735160  ...       903320  24323230
# 3           530250               0  ...            0    851215
# 4           810700          125760  ...       771770   5042106
# 5          1325670          415330  ...       218570   5460150
# ...            ...             ...  ...          ...       ...
# 19356        87670               0  ...            0    170160
# 19357        29650               0  ...            0     91950
# 19359        12300               0  ...            0     43190
# 19360        83750               0  ...            0    368050
# 19364        58600               0  ...            0   2032420
#
# [19085 rows x 12 columns]

# %%
trainlist = [1,2]
c_li = list(p1.columns)
train = train.reset_index()

trainList = ['고객번호']
for col in c_li:
  for h in trainlist:
    trainList.append(f'{col}_{h}')
train = train[['고객번호',
 '가공식품_구매금액_1',
 '가공식품_구매금액_2',
 '가구/인테리어_구매금액_1',
 '가구/인테리어_구매금액_2',
 '교육/문화용품_구매금액_1',
 '교육/문화용품_구매금액_2',
 '기타_구매금액_1',
 '기타_구매금액_2',
 '디지털/가전_구매금액_1',
 '디지털/가전_구매금액_2',
 '명품_구매금액_1',
 '명품_구매금액_2',
 '신선식품_구매금액_1',
 '신선식품_구매금액_2',
 '의류_구매금액_1',
 '의류_구매금액_2',
 '일상용품_구매금액_1',
 '일상용품_구매금액_2',
 '전문스포츠/레저_구매금액_1',
 '전문스포츠/레저_구매금액_2',
 '패션잡화_구매금액_1',
 '패션잡화_구매금액_2']]

# %%
train
# Out:
#         고객번호  가공식품_구매금액_1  ...  패션잡화_구매금액_1  패션잡화_구매금액_2
# 0          1      3550030  ...      1716860      1634580
# 1          2      1485380  ...       903320       617490
# 2          3       530250  ...            0            0
# 3          4       810700  ...       771770       241300
# 4          5      1325670  ...       218570        69000
# ...      ...          ...  ...          ...          ...
# 19080  19356        87670  ...            0            0
# 19081  19357        29650  ...            0        91900
# 19082  19359        12300  ...            0            0
# 19083  19360        83750  ...            0            0
# 19084  19364        58600  ...            0       526500
#
# [19085 rows x 23 columns]

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/10월14일이후 새로추가/train/B_clf_total_amt_ratio.pkl','wb') as train_save:
  pickle.dump(train,train_save)

# %%
def new_test_df(a,b,c):
    A = pd.concat([a,b],axis=1)
    train = pd.concat([A,c],axis=1)    
    return train

test = new_test_df(H1,H2,H3)

# %%
test
# Out:
#        가공식품_구매금액_1  가구/인테리어_구매금액_1  ...  패션잡화_구매금액_3   총구매금액_3
# 고객번호                                ...
# 1          3550030          696520  ...      1006860  17898365
# 2          1485380         1735160  ...       755770  27791610
# 3           530250               0  ...            0    592280
# 4           810700          125760  ...        76600   3656937
# 5          1325670          415330  ...            0   2934930
# ...            ...             ...  ...          ...       ...
# 19356        87670               0  ...            0   2104968
# 19357        29650               0  ...       378200   3044944
# 19359        12300               0  ...            0    837240
# 19360        83750               0  ...        94000   1412140
# 19364        58600               0  ...       139000   3218130
#
# [19085 rows x 36 columns]

# %%
testlist = [1,2,3]
c_li = list(p1.columns)

testList = []
for col in c_li:
  for h in testlist:
    testList.append(f'{col}_{h}')
test = test[['가공식품_구매금액_1',
 '가공식품_구매금액_2',
 '가공식품_구매금액_3',
 '가구/인테리어_구매금액_1',
 '가구/인테리어_구매금액_2',
 '가구/인테리어_구매금액_3',
 '교육/문화용품_구매금액_1',
 '교육/문화용품_구매금액_2',
 '교육/문화용품_구매금액_3',
 '기타_구매금액_1',
 '기타_구매금액_2',
 '기타_구매금액_3',
 '디지털/가전_구매금액_1',
 '디지털/가전_구매금액_2',
 '디지털/가전_구매금액_3',
 '명품_구매금액_1',
 '명품_구매금액_2',
 '명품_구매금액_3',
 '신선식품_구매금액_1',
 '신선식품_구매금액_2',
 '신선식품_구매금액_3',
 '의류_구매금액_1',
 '의류_구매금액_2',
 '의류_구매금액_3',
 '일상용품_구매금액_1',
 '일상용품_구매금액_2',
 '일상용품_구매금액_3',
 '전문스포츠/레저_구매금액_1',
 '전문스포츠/레저_구매금액_2',
 '전문스포츠/레저_구매금액_3',
 '패션잡화_구매금액_1',
 '패션잡화_구매금액_2',
 '패션잡화_구매금액_3']]

# %%
test = test.reset_index()
test
# Out:
#         고객번호  가공식품_구매금액_1  가공식품_구매금액_2  ...  패션잡화_구매금액_1  패션잡화_구매금액_2  패션잡화_구매금액_3
# 0          1      3550030      1642040  ...      1716860      1634580      1006860
# 1          2      1485380      1210600  ...       903320       617490       755770
# 2          3       530250       571720  ...            0            0            0
# 3          4       810700       517130  ...       771770       241300        76600
# 4          5      1325670       696000  ...       218570        69000            0
# ...      ...          ...          ...  ...          ...          ...          ...
# 19080  19356        87670       827830  ...            0            0            0
# 19081  19357        29650      1417440  ...            0        91900       378200
# 19082  19359        12300       791220  ...            0            0            0
# 19083  19360        83750       421580  ...            0            0        94000
# 19084  19364        58600       216850  ...            0       526500       139000
#
# [19085 rows x 34 columns]

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/10월14일이후 새로추가/test/B_clf_total_amt_ratio.pkl','wb') as test_save:
  pickle.dump(test,test_save)
