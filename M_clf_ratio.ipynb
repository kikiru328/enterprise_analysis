# %% [markdown]
# <a href="https://colab.research.google.com/github/kikiru328/enterprise_analysis/blob/main/M_clf_ratio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
my_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', my_path)
sys.path.insert(0,my_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-128-917b5458b89a> in <module>()
#       3 drive.mount('/content/drive')
#       4 my_path = '/content/notebooks'
# ----> 5 os.symlink('/content/drive/My Drive/Colab Notebooks', my_path)
#       6 sys.path.insert(0,my_path)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/My Drive/Colab Notebooks' -> '/content/notebooks'

# %%
#  Directory 변경 (모듈이용)
# %pwd
# %cd '../content/notebooks'

# module import
## Data Load
from pickle5 import pickle 

## Basic module
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/data/EDA/기존_purprd_cust.pkl','rb') as file:
  df = pickle.load(file)

# %%
df['고객번호'].unique()
# Out:
# array([15148,   400,  2043, ...,  8477, 11171, 14153])

# %%
m1 = df[(df['구매년도']==2014)&(df['구매월']==1)]
m2 = df[(df['구매년도']==2014)&(df['구매월']==2)]
m3 = df[(df['구매년도']==2014)&(df['구매월']==3)]
m4 = df[(df['구매년도']==2014)&(df['구매월']==4)]
m5 = df[(df['구매년도']==2014)&(df['구매월']==5)]
m6 = df[(df['구매년도']==2014)&(df['구매월']==6)]
m7 = df[(df['구매년도']==2014)&(df['구매월']==7)]
m8 = df[(df['구매년도']==2014)&(df['구매월']==8)]
m9 = df[(df['구매년도']==2014)&(df['구매월']==9)]
m10 = df[(df['구매년도']==2014)&(df['구매월']==10)]
m11= df[(df['구매년도']==2014)&(df['구매월']==11)]
m12= df[(df['구매년도']==2015)&(df['구매월']==12)]

m13 = df[(df['구매년도']==2015)&(df['구매월']==1)]
m14 = df[(df['구매년도']==2015)&(df['구매월']==2)]
m15= df[(df['구매년도']==2015)&(df['구매월']==3)]
m16 = df[(df['구매년도']==2015)&(df['구매월']==4)]
m17 = df[(df['구매년도']==2015)&(df['구매월']==5)]
m18 = df[(df['구매년도']==2015)&(df['구매월']==6)]
m19 = df[(df['구매년도']==2015)&(df['구매월']==7)]
m20 = df[(df['구매년도']==2015)&(df['구매월']==8)]
m21 = df[(df['구매년도']==2015)&(df['구매월']==9)]
m22 = df[(df['구매년도']==2015)&(df['구매월']==10)]
m23 = df[(df['구매년도']==2015)&(df['구매월']==11)]
m24 = df[(df['구매년도']==2015)&(df['구매월']==12)]

# %%
def ratio(df):
  test = df[['고객번호','대분류명']]
  test = test.set_index('고객번호')
  A = pd.get_dummies(test['대분류명']).reset_index()
  A = A.groupby('고객번호').sum().astype(int)
  Li = list(A.columns)
  A['total'] = A.sum(axis=1).astype(int)
  for i in Li:
    A[f"{i}_r"] = A[i] / A['total']
  B = A.drop(['가공식품', '가구/인테리어', '교육/문화용품', '기타', '디지털/가전', '명품', '신선식품', '의류',
    '일상용품', '전문스포츠/레저', '패션잡화','total'],axis=1)
  B['total_r'] = B.sum(axis=1)
  return B

# %%
m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12 = ratio(m1),ratio(m2),ratio(m3),ratio(m4),ratio(m5),ratio(m6),ratio(m7),ratio(m8),ratio(m9),ratio(m10),ratio(m11),ratio(m12)
m13,m14,m15,m16,m17,m18,m19,m20,m21,m22,m23,m24 = ratio(m13),ratio(m14),ratio(m15),ratio(m16),ratio(m17),ratio(m18),ratio(m19),ratio(m20),ratio(m21),ratio(m22),ratio(m23),ratio(m24)

# %%
def new_reName(a,df):
    cols = list(df.columns)
    for i in cols:
      df[f'{i}_{a}'] = df[i]
    A = df.drop(cols,axis=1)
    A = A.reset_index()
    return A

# %%
m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12 = new_reName(1,m1),new_reName(2,m2),new_reName(3,m3),new_reName(4,m4),new_reName(5,m5),new_reName(6,m6),new_reName(7,m7),new_reName(8,m8),new_reName(9,m9),new_reName(10,m10),new_reName(11,m11),new_reName(12,m12)
m13,m14,m15,m16,m17,m18,m19,m20,m21,m22,m23,m24 = new_reName(13,m13),new_reName(14,m14),new_reName(15,m15),new_reName(16,m16),new_reName(17,m17),new_reName(18,m18),new_reName(19,m19),new_reName(20,m20),new_reName(21,m21),new_reName(22,m22),new_reName(23,m23),new_reName(24,m24)

# %%
trainL = [m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12]
testL = [m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12,m13,m14,m15,m16,m17,m18]

# %%
a = df[['고객번호','구매금액']]
a = a.groupby('고객번호').sum()
a = a.reset_index()
train_bin = a[['고객번호']]
train_bin
# Out:
#         고객번호
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 19080  19356
# 19081  19357
# 19082  19359
# 19083  19360
# 19084  19364
#
# [19085 rows x 1 columns]

# %%
def new_train_df(A):
  global train_bin
  for i in A:
    train_bin = pd.merge(train_bin,i,on='고객번호',how='left')
  return train_bin

# %%
train = new_train_df(trainL)

# %%
train = train.fillna(0)

# %%
train

# %%
col_standard =  df[(df['구매년도']==2014)&(df['구매월']==1)]
col_standard = ratio(col_standard)
col_standard = list(col_standard.columns)

# %%
가공식품_r_1

# %%
trainlist =list(range(1,13))
col_standard


trainList = []
for col in col_standard:
  for h in trainlist:
    trainList.append(f'{col}_{h}')

# train = train[trainList]

trainList = ['고객번호','가공식품_r_1',
 '가공식품_r_2',
 '가공식품_r_3',
 '가공식품_r_4',
 '가공식품_r_5',
 '가공식품_r_6',
 '가공식품_r_7',
 '가공식품_r_8',
 '가공식품_r_9',
 '가공식품_r_10',
 '가공식품_r_11',
 '가공식품_r_12',
 '가구/인테리어_r_1',
 '가구/인테리어_r_2',
 '가구/인테리어_r_3',
 '가구/인테리어_r_4',
 '가구/인테리어_r_5',
 '가구/인테리어_r_6',
 '가구/인테리어_r_7',
 '가구/인테리어_r_8',
 '가구/인테리어_r_9',
 '가구/인테리어_r_10',
 '가구/인테리어_r_11',
 '가구/인테리어_r_12',
 '교육/문화용품_r_1',
 '교육/문화용품_r_2',
 '교육/문화용품_r_3',
 '교육/문화용품_r_4',
 '교육/문화용품_r_5',
 '교육/문화용품_r_6',
 '교육/문화용품_r_7',
 '교육/문화용품_r_8',
 '교육/문화용품_r_9',
 '교육/문화용품_r_10',
 '교육/문화용품_r_11',
 '교육/문화용품_r_12',
 '기타_r_1',
 '기타_r_2',
 '기타_r_3',
 '기타_r_4',
 '기타_r_5',
 '기타_r_6',
 '기타_r_7',
 '기타_r_8',
 '기타_r_9',
 '기타_r_10',
 '기타_r_11',
 '기타_r_12',
 '디지털/가전_r_1',
 '디지털/가전_r_2',
 '디지털/가전_r_3',
 '디지털/가전_r_4',
 '디지털/가전_r_5',
 '디지털/가전_r_6',
 '디지털/가전_r_7',
 '디지털/가전_r_8',
 '디지털/가전_r_9',
 '디지털/가전_r_10',
 '디지털/가전_r_11',
 '디지털/가전_r_12',
 '명품_r_1',
 '명품_r_2',
 '명품_r_3',
 '명품_r_4',
 '명품_r_5',
 '명품_r_6',
 '명품_r_7',
 '명품_r_8',
 '명품_r_9',
 '명품_r_10',
 '명품_r_11',
 '명품_r_12',
 '신선식품_r_1',
 '신선식품_r_2',
 '신선식품_r_3',
 '신선식품_r_4',
 '신선식품_r_5',
 '신선식품_r_6',
 '신선식품_r_7',
 '신선식품_r_8',
 '신선식품_r_9',
 '신선식품_r_10',
 '신선식품_r_11',
 '신선식품_r_12',
 '의류_r_1',
 '의류_r_2',
 '의류_r_3',
 '의류_r_4',
 '의류_r_5',
 '의류_r_6',
 '의류_r_7',
 '의류_r_8',
 '의류_r_9',
 '의류_r_10',
 '의류_r_11',
 '의류_r_12',
 '일상용품_r_1',
 '일상용품_r_2',
 '일상용품_r_3',
 '일상용품_r_4',
 '일상용품_r_5',
 '일상용품_r_6',
 '일상용품_r_7',
 '일상용품_r_8',
 '일상용품_r_9',
 '일상용품_r_10',
 '일상용품_r_11',
 '일상용품_r_12',
 '전문스포츠/레저_r_1',
 '전문스포츠/레저_r_2',
 '전문스포츠/레저_r_3',
 '전문스포츠/레저_r_4',
 '전문스포츠/레저_r_5',
 '전문스포츠/레저_r_6',
 '전문스포츠/레저_r_7',
 '전문스포츠/레저_r_8',
 '전문스포츠/레저_r_9',
 '전문스포츠/레저_r_10',
 '전문스포츠/레저_r_11',
 '전문스포츠/레저_r_12',
 '패션잡화_r_1',
 '패션잡화_r_2',
 '패션잡화_r_3',
 '패션잡화_r_4',
 '패션잡화_r_5',
 '패션잡화_r_6',
 '패션잡화_r_7',
 '패션잡화_r_8',
 '패션잡화_r_9',
 '패션잡화_r_10',
 '패션잡화_r_11',
 '패션잡화_r_12'
 ]
train=train[trainList]
train

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/월별/train/m_ratio.pkl','wb') as train_save:
  pickle.dump(train,train_save)

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/월별/train/m_ratio.pkl','rb') as train_save:
  A = pickle.load(train_save)
A
# Out:
#         고객번호  가공식품_r_1  가공식품_r_2  ...  패션잡화_r_10  패션잡화_r_11  패션잡화_r_12
# 0          1  0.261905  0.266667  ...   0.081081   0.019231   0.037037
# 1          2  0.180556  0.081633  ...   0.000000   0.148148   0.069767
# 2          3  0.649123  0.708333  ...   0.000000   0.000000   0.000000
# 3          4  0.375000  0.416667  ...   0.000000   0.000000   0.062500
# 4          5  0.426471  0.344828  ...   0.000000   0.000000   0.050000
# ...      ...       ...       ...  ...        ...        ...        ...
# 19080  19356  0.000000  0.000000  ...   0.000000   0.000000   0.000000
# 19081  19357  0.000000  0.000000  ...   0.000000   0.013514   0.000000
# 19082  19359  0.000000  0.000000  ...   0.000000   0.000000   0.000000
# 19083  19360  0.000000  0.000000  ...   0.000000   0.000000   0.000000
# 19084  19364  0.000000  0.000000  ...   0.000000   0.000000   0.000000
#
# [19085 rows x 133 columns]

# %%
testL = [m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12,m13,m14,m15,m16,m17,m18]

# %%
def new_test_df(A):
  global train_bin
  for i in A:
    train_bin = pd.merge(train_bin,i,on='고객번호',how='left')
  return train_bin

# %%
test = new_test_df(testL)
test = test.fillna(0)
test
# Out:
#         고객번호  가공식품_r_1  가구/인테리어_r_1  ...  전문스포츠/레저_r_18  패션잡화_r_18  total_r_18
# 0          1  0.261905     0.142857  ...            0.0   0.000000         1.0
# 1          2  0.180556     0.083333  ...            0.0   0.000000         1.0
# 2          3  0.649123     0.000000  ...            0.0   0.000000         1.0
# 3          4  0.375000     0.000000  ...            0.0   0.000000         1.0
# 4          5  0.426471     0.088235  ...            0.0   0.000000         0.0
# ...      ...       ...          ...  ...            ...        ...         ...
# 19080  19356  0.000000     0.000000  ...            0.0   0.000000         1.0
# 19081  19357  0.000000     0.000000  ...            0.0   0.000000         1.0
# 19082  19359  0.000000     0.000000  ...            0.0   0.000000         1.0
# 19083  19360  0.000000     0.000000  ...            0.0   0.000000         1.0
# 19084  19364  0.000000     0.000000  ...            0.0   0.019231         1.0
#
# [19085 rows x 217 columns]

# %%
testlist = list(range(1,19))
c_li = col_standard

testList = []
for col in col_standard:
  for h in testlist:
    testList.append(f'{col}_{h}')

testList = ['가공식품_r_1',
 '가공식품_r_2',
 '가공식품_r_3',
 '가공식품_r_4',
 '가공식품_r_5',
 '가공식품_r_6',
 '가공식품_r_7',
 '가공식품_r_8',
 '가공식품_r_9',
 '가공식품_r_10',
 '가공식품_r_11',
 '가공식품_r_12',
 '가공식품_r_13',
 '가공식품_r_14',
 '가공식품_r_15',
 '가공식품_r_16',
 '가공식품_r_17',
 '가공식품_r_18',
 '가구/인테리어_r_1',
 '가구/인테리어_r_2',
 '가구/인테리어_r_3',
 '가구/인테리어_r_4',
 '가구/인테리어_r_5',
 '가구/인테리어_r_6',
 '가구/인테리어_r_7',
 '가구/인테리어_r_8',
 '가구/인테리어_r_9',
 '가구/인테리어_r_10',
 '가구/인테리어_r_11',
 '가구/인테리어_r_12',
 '가구/인테리어_r_13',
 '가구/인테리어_r_14',
 '가구/인테리어_r_15',
 '가구/인테리어_r_16',
 '가구/인테리어_r_17',
 '가구/인테리어_r_18',
 '교육/문화용품_r_1',
 '교육/문화용품_r_2',
 '교육/문화용품_r_3',
 '교육/문화용품_r_4',
 '교육/문화용품_r_5',
 '교육/문화용품_r_6',
 '교육/문화용품_r_7',
 '교육/문화용품_r_8',
 '교육/문화용품_r_9',
 '교육/문화용품_r_10',
 '교육/문화용품_r_11',
 '교육/문화용품_r_12',
 '교육/문화용품_r_13',
 '교육/문화용품_r_14',
 '교육/문화용품_r_15',
 '교육/문화용품_r_16',
 '교육/문화용품_r_17',
 '교육/문화용품_r_18',
 '기타_r_1',
 '기타_r_2',
 '기타_r_3',
 '기타_r_4',
 '기타_r_5',
 '기타_r_6',
 '기타_r_7',
 '기타_r_8',
 '기타_r_9',
 '기타_r_10',
 '기타_r_11',
 '기타_r_12',
 '기타_r_13',
 '기타_r_14',
 '기타_r_15',
 '기타_r_16',
 '기타_r_17',
 '기타_r_18',
 '디지털/가전_r_1',
 '디지털/가전_r_2',
 '디지털/가전_r_3',
 '디지털/가전_r_4',
 '디지털/가전_r_5',
 '디지털/가전_r_6',
 '디지털/가전_r_7',
 '디지털/가전_r_8',
 '디지털/가전_r_9',
 '디지털/가전_r_10',
 '디지털/가전_r_11',
 '디지털/가전_r_12',
 '디지털/가전_r_13',
 '디지털/가전_r_14',
 '디지털/가전_r_15',
 '디지털/가전_r_16',
 '디지털/가전_r_17',
 '디지털/가전_r_18',
 '명품_r_1',
 '명품_r_2',
 '명품_r_3',
 '명품_r_4',
 '명품_r_5',
 '명품_r_6',
 '명품_r_7',
 '명품_r_8',
 '명품_r_9',
 '명품_r_10',
 '명품_r_11',
 '명품_r_12',
 '명품_r_13',
 '명품_r_14',
 '명품_r_15',
 '명품_r_16',
 '명품_r_17',
 '명품_r_18',
 '신선식품_r_1',
 '신선식품_r_2',
 '신선식품_r_3',
 '신선식품_r_4',
 '신선식품_r_5',
 '신선식품_r_6',
 '신선식품_r_7',
 '신선식품_r_8',
 '신선식품_r_9',
 '신선식품_r_10',
 '신선식품_r_11',
 '신선식품_r_12',
 '신선식품_r_13',
 '신선식품_r_14',
 '신선식품_r_15',
 '신선식품_r_16',
 '신선식품_r_17',
 '신선식품_r_18',
 '의류_r_1',
 '의류_r_2',
 '의류_r_3',
 '의류_r_4',
 '의류_r_5',
 '의류_r_6',
 '의류_r_7',
 '의류_r_8',
 '의류_r_9',
 '의류_r_10',
 '의류_r_11',
 '의류_r_12',
 '의류_r_13',
 '의류_r_14',
 '의류_r_15',
 '의류_r_16',
 '의류_r_17',
 '의류_r_18',
 '일상용품_r_1',
 '일상용품_r_2',
 '일상용품_r_3',
 '일상용품_r_4',
 '일상용품_r_5',
 '일상용품_r_6',
 '일상용품_r_7',
 '일상용품_r_8',
 '일상용품_r_9',
 '일상용품_r_10',
 '일상용품_r_11',
 '일상용품_r_12',
 '일상용품_r_13',
 '일상용품_r_14',
 '일상용품_r_15',
 '일상용품_r_16',
 '일상용품_r_17',
 '일상용품_r_18',
 '전문스포츠/레저_r_1',
 '전문스포츠/레저_r_2',
 '전문스포츠/레저_r_3',
 '전문스포츠/레저_r_4',
 '전문스포츠/레저_r_5',
 '전문스포츠/레저_r_6',
 '전문스포츠/레저_r_7',
 '전문스포츠/레저_r_8',
 '전문스포츠/레저_r_9',
 '전문스포츠/레저_r_10',
 '전문스포츠/레저_r_11',
 '전문스포츠/레저_r_12',
 '전문스포츠/레저_r_13',
 '전문스포츠/레저_r_14',
 '전문스포츠/레저_r_15',
 '전문스포츠/레저_r_16',
 '전문스포츠/레저_r_17',
 '전문스포츠/레저_r_18',
 '패션잡화_r_1',
 '패션잡화_r_2',
 '패션잡화_r_3',
 '패션잡화_r_4',
 '패션잡화_r_5',
 '패션잡화_r_6',
 '패션잡화_r_7',
 '패션잡화_r_8',
 '패션잡화_r_9',
 '패션잡화_r_10',
 '패션잡화_r_11',
 '패션잡화_r_12',
 '패션잡화_r_13',
 '패션잡화_r_14',
 '패션잡화_r_15',
 '패션잡화_r_16',
 '패션잡화_r_17',
 '패션잡화_r_18']

test = test[testList]
test
# Out:
#        가공식품_r_1  가공식품_r_2  가공식품_r_3  ...  패션잡화_r_16  패션잡화_r_17  패션잡화_r_18
# 0      0.261905  0.266667  0.294118  ...   0.019608   0.028571   0.000000
# 1      0.180556  0.081633  0.142857  ...   0.116279   0.111111   0.000000
# 2      0.649123  0.708333  0.823529  ...   0.000000   0.000000   0.000000
# 3      0.375000  0.416667  0.378378  ...   0.000000   0.114286   0.000000
# 4      0.426471  0.344828  0.310345  ...   0.000000   0.000000   0.000000
# ...         ...       ...       ...  ...        ...        ...        ...
# 19080  0.000000  0.000000  0.000000  ...   0.000000   0.000000   0.000000
# 19081  0.000000  0.000000  0.000000  ...   0.000000   0.014493   0.000000
# 19082  0.000000  0.000000  0.000000  ...   0.000000   0.000000   0.000000
# 19083  0.000000  0.000000  0.000000  ...   0.000000   0.000000   0.000000
# 19084  0.000000  0.000000  0.000000  ...   0.018519   0.000000   0.019231
#
# [19085 rows x 198 columns]

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/월별/test/m_ratio.pkl','wb') as test_save:
  pickle.dump(test,test_save)
