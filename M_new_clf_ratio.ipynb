# %% [markdown]
# <a href="https://colab.research.google.com/github/kikiru328/enterprise_analysis/blob/main/M_new_clf_ratio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
my_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', my_path)
sys.path.insert(0,my_path)
# Out:
# Mounted at /content/drive

# %%
#  Directory 변경 (모듈이용)
# %pwd
# %cd '../content/notebooks'

# module import
## Data Load
from pickle5 import pickle 

## Basic module
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
# Out:
# [Errno 2] No such file or directory: '../content/notebooks'
# /content/drive/My Drive/Colab Notebooks

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/훈팡/새분류.pkl','rb') as file:
  df = pickle.load(file)

# %%
df['고객번호'].unique()
# Out:
# array([15148,  2043,  2231, ..., 11653, 13918,  8770])

# %%
m1 = df[(df['구매년도']==2014)&(df['구매월']==1)]
m2 = df[(df['구매년도']==2014)&(df['구매월']==2)]
m3 = df[(df['구매년도']==2014)&(df['구매월']==3)]
m4 = df[(df['구매년도']==2014)&(df['구매월']==4)]
m5 = df[(df['구매년도']==2014)&(df['구매월']==5)]
m6 = df[(df['구매년도']==2014)&(df['구매월']==6)]
m7 = df[(df['구매년도']==2014)&(df['구매월']==7)]
m8 = df[(df['구매년도']==2014)&(df['구매월']==8)]
m9 = df[(df['구매년도']==2014)&(df['구매월']==9)]
m10 = df[(df['구매년도']==2014)&(df['구매월']==10)]
m11 = df[(df['구매년도']==2014)&(df['구매월']==11)]
m12 = df[(df['구매년도']==2014)&(df['구매월']==12)]

m13 = df[(df['구매년도']==2015)&(df['구매월']==1)]
m14 = df[(df['구매년도']==2015)&(df['구매월']==2)]
m15 = df[(df['구매년도']==2015)&(df['구매월']==3)]
m16 = df[(df['구매년도']==2015)&(df['구매월']==4)]
m17 = df[(df['구매년도']==2015)&(df['구매월']==5)]
m18 = df[(df['구매년도']==2015)&(df['구매월']==6)]
m19 = df[(df['구매년도']==2015)&(df['구매월']==7)]
m20 = df[(df['구매년도']==2015)&(df['구매월']==8)]
m21 = df[(df['구매년도']==2015)&(df['구매월']==9)]
m22 = df[(df['구매년도']==2015)&(df['구매월']==10)]
m23 = df[(df['구매년도']==2015)&(df['구매월']==11)]
m24 = df[(df['구매년도']==2015)&(df['구매월']==12)]

# %%
m1.새분류.unique()
# Out:
# array(['내구재', '준내구재', '비내구재', '사치품'], dtype=object)

# %%
def ratio(df):
  test = df[['고객번호','새분류']]
  test = test.set_index('고객번호')
  A = pd.get_dummies(test['새분류']).reset_index()
  A = A.groupby('고객번호').sum().astype(int)
  Li = list(A.columns)
  A['total'] = A.sum(axis=1).astype(int)
  for i in Li:
    A[f"{i}_r"] = A[i] / A['total']
  B = A.drop(['내구재', '준내구재', '비내구재', '사치품','total'],axis=1)
  B['total_r'] = B.sum(axis=1)
  return B

# %%
m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12 = ratio(m1),ratio(m2),ratio(m3),ratio(m4),ratio(m5),ratio(m6),ratio(m7),ratio(m8),ratio(m9),ratio(m10),ratio(m11),ratio(m12)
m13,m14,m15,m16,m17,m18,m19,m20,m21,m22,m23,m24 = ratio(m13),ratio(m14),ratio(m15),ratio(m16),ratio(m17),ratio(m18),ratio(m19),ratio(m20),ratio(m21),ratio(m22),ratio(m23),ratio(m24)

# %%
m1
# Out:
#           내구재_r    비내구재_r  사치품_r    준내구재_r  total_r
# 고객번호
# 1      0.000000  0.738095    0.0  0.261905      1.0
# 2      0.055556  0.847222    0.0  0.097222      1.0
# 3      0.000000  1.000000    0.0  0.000000      1.0
# 4      0.000000  0.968750    0.0  0.031250      1.0
# 5      0.000000  0.985294    0.0  0.014706      1.0
# ...         ...       ...    ...       ...      ...
# 19318  0.037037  0.888889    0.0  0.074074      1.0
# 19319  0.000000  1.000000    0.0  0.000000      1.0
# 19320  0.021277  0.914894    0.0  0.063830      1.0
# 19322  0.000000  1.000000    0.0  0.000000      1.0
# 19325  0.000000  1.000000    0.0  0.000000      1.0
#
# [18647 rows x 5 columns]

# %%
def new_reName(a,df):
    cols = list(df.columns)
    for i in cols:
      df[f'{i}_{a}'] = df[i]
    A = df.drop(cols,axis=1)
    A = A.reset_index()
    return A

# %%
m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12 = new_reName(1,m1),new_reName(2,m2),new_reName(3,m3),new_reName(4,m4),new_reName(5,m5),new_reName(6,m6),new_reName(7,m7),new_reName(8,m8),new_reName(9,m9),new_reName(10,m10),new_reName(11,m11),new_reName(12,m12)
m13,m14,m15,m16,m17,m18,m19,m20,m21,m22,m23,m24 = new_reName(13,m13),new_reName(14,m14),new_reName(15,m15),new_reName(16,m16),new_reName(17,m17),new_reName(18,m18),new_reName(19,m19),new_reName(20,m20),new_reName(21,m21),new_reName(22,m22),new_reName(23,m23),new_reName(24,m24)

# %%
m1
# Out:
#         고객번호   내구재_r_1  비내구재_r_1  사치품_r_1  준내구재_r_1  total_r_1
# 0          1  0.000000  0.738095      0.0  0.261905        1.0
# 1          2  0.055556  0.847222      0.0  0.097222        1.0
# 2          3  0.000000  1.000000      0.0  0.000000        1.0
# 3          4  0.000000  0.968750      0.0  0.031250        1.0
# 4          5  0.000000  0.985294      0.0  0.014706        1.0
# ...      ...       ...       ...      ...       ...        ...
# 18642  19318  0.037037  0.888889      0.0  0.074074        1.0
# 18643  19319  0.000000  1.000000      0.0  0.000000        1.0
# 18644  19320  0.021277  0.914894      0.0  0.063830        1.0
# 18645  19322  0.000000  1.000000      0.0  0.000000        1.0
# 18646  19325  0.000000  1.000000      0.0  0.000000        1.0
#
# [18647 rows x 6 columns]

# %%
trainL = [m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12]
testL = [m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12,m13,m14,m15,m16,m17,m18]

# %%
a = df[['고객번호','구매금액']]
a = a.groupby('고객번호').sum()
a = a.reset_index()
train_bin = a[['고객번호']]
train_bin
# Out:
#         고객번호
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 19080  19356
# 19081  19357
# 19082  19359
# 19083  19360
# 19084  19364
#
# [19085 rows x 1 columns]

# %%
def new_train_df(A):
  global train_bin
  for i in A:
    train_bin = pd.merge(train_bin,i,on='고객번호',how='left')
  return train_bin

# %%
train = new_train_df(trainL)

# %%
train = train.fillna(0)

# %%
train
# Out:
#         고객번호   내구재_r_1  비내구재_r_1  ...  사치품_r_12  준내구재_r_12  total_r_12
# 0          1  0.000000  0.738095  ...  0.000000   0.159091         1.0
# 1          2  0.055556  0.847222  ...  0.000000   0.017857         1.0
# 2          3  0.000000  1.000000  ...  0.000000   0.000000         1.0
# 3          4  0.000000  0.968750  ...  0.000000   0.147059         1.0
# 4          5  0.000000  0.985294  ...  0.000000   0.000000         1.0
# ...      ...       ...       ...  ...       ...        ...         ...
# 19080  19356  0.000000  0.000000  ...  0.000000   0.000000         1.0
# 19081  19357  0.000000  0.000000  ...  0.000000   0.037736         1.0
# 19082  19359  0.000000  0.000000  ...  0.000000   0.000000         1.0
# 19083  19360  0.000000  0.000000  ...  0.000000   0.027778         1.0
# 19084  19364  0.000000  0.000000  ...  0.014925   0.044776         1.0
#
# [19085 rows x 61 columns]

# %%
col_standard =  df[(df['구매년도']==2014)&(df['구매월']==1)]
col_standard = ratio(col_standard)
col_standard = list(col_standard.columns)

# %%
# trainlist =list(range(1,13))
# col_standard


# trainList = []
# for col in col_standard:
#   for h in trainlist:
#     trainList.append(f'{col}_{h}')

# train = train[trainList]

trainList=['고객번호','내구재_r_1',
 '내구재_r_2',
 '내구재_r_3',
 '내구재_r_4',
 '내구재_r_5',
 '내구재_r_6',
 '내구재_r_7',
 '내구재_r_8',
 '내구재_r_9',
 '내구재_r_10',
 '내구재_r_11',
 '내구재_r_12',
 '준내구재_r_1',
 '준내구재_r_2',
 '준내구재_r_3',
 '준내구재_r_4',
 '준내구재_r_5',
 '준내구재_r_6',
 '준내구재_r_7',
 '준내구재_r_8',
 '준내구재_r_9',
 '준내구재_r_10',
 '준내구재_r_11',
 '준내구재_r_12',
 '비내구재_r_1',
 '비내구재_r_2',
 '비내구재_r_3',
 '비내구재_r_4',
 '비내구재_r_5',
 '비내구재_r_6',
 '비내구재_r_7',
 '비내구재_r_8',
 '비내구재_r_9',
 '비내구재_r_10',
 '비내구재_r_11',
 '비내구재_r_12',
 '사치품_r_1',
 '사치품_r_2',
 '사치품_r_3',
 '사치품_r_4',
 '사치품_r_5',
 '사치품_r_6',
 '사치품_r_7',
 '사치품_r_8',
 '사치품_r_9',
 '사치품_r_10',
 '사치품_r_11',
 '사치품_r_12',
 ]

train = train[trainList]
train
# Out:
#         고객번호   내구재_r_1   내구재_r_2  ...  사치품_r_10  사치품_r_11  사치품_r_12
# 0          1  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1          2  0.055556  0.040816  ...  0.000000  0.037037  0.000000
# 2          3  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3          4  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4          5  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# ...      ...       ...       ...  ...       ...       ...       ...
# 19080  19356  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 19081  19357  0.000000  0.000000  ...  0.013699  0.000000  0.000000
# 19082  19359  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 19083  19360  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 19084  19364  0.000000  0.000000  ...  0.000000  0.000000  0.014925
#
# [19085 rows x 49 columns]

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/월별/train/m_new_ratio.pkl','wb') as train_save:
  pickle.dump(train,train_save)

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/월별/train/m_new_ratio.pkl','rb') as train_save:
  A = pickle.load(train_save)
A
# Out:
#         고객번호   내구재_r_1   내구재_r_2  ...  사치품_r_10  사치품_r_11  사치품_r_12
# 0          1  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1          2  0.055556  0.040816  ...  0.000000  0.037037  0.000000
# 2          3  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3          4  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4          5  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# ...      ...       ...       ...  ...       ...       ...       ...
# 19080  19356  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 19081  19357  0.000000  0.000000  ...  0.013699  0.000000  0.000000
# 19082  19359  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 19083  19360  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 19084  19364  0.000000  0.000000  ...  0.000000  0.000000  0.014925
#
# [19085 rows x 49 columns]

# %%
testL = [m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12,m13,m14,m15,m16,m17,m18]

# %%
m1
# Out:
#         고객번호   내구재_r_1  비내구재_r_1  사치품_r_1  준내구재_r_1  total_r_1
# 0          1  0.000000  0.738095      0.0  0.261905        1.0
# 1          2  0.055556  0.847222      0.0  0.097222        1.0
# 2          3  0.000000  1.000000      0.0  0.000000        1.0
# 3          4  0.000000  0.968750      0.0  0.031250        1.0
# 4          5  0.000000  0.985294      0.0  0.014706        1.0
# ...      ...       ...       ...      ...       ...        ...
# 18642  19318  0.037037  0.888889      0.0  0.074074        1.0
# 18643  19319  0.000000  1.000000      0.0  0.000000        1.0
# 18644  19320  0.021277  0.914894      0.0  0.063830        1.0
# 18645  19322  0.000000  1.000000      0.0  0.000000        1.0
# 18646  19325  0.000000  1.000000      0.0  0.000000        1.0
#
# [18647 rows x 6 columns]

# %%
a = df[['고객번호','구매금액']]
a = a.groupby('고객번호').sum()
a = a.reset_index()
train_bin = a[['고객번호']]
train_bin
# Out:
#         고객번호
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 19080  19356
# 19081  19357
# 19082  19359
# 19083  19360
# 19084  19364
#
# [19085 rows x 1 columns]

# %%
def new_test_df(A):
  global train_bin
  for i in A:
    train_bin = pd.merge(train_bin,i,on='고객번호',how='left')
  return train_bin

# %%
test= new_test_df(testL)
test = test.fillna(0)
test
# Out:
#         고객번호   내구재_r_1  비내구재_r_1  ...  사치품_r_18  준내구재_r_18  total_r_18
# 0          1  0.000000  0.738095  ...       0.0   0.148148         1.0
# 1          2  0.055556  0.847222  ...       0.0   0.071429         1.0
# 2          3  0.000000  1.000000  ...       0.0   0.000000         1.0
# 3          4  0.000000  0.968750  ...       0.0   0.079365         1.0
# 4          5  0.000000  0.985294  ...       0.0   0.000000         0.0
# ...      ...       ...       ...  ...       ...        ...         ...
# 19080  19356  0.000000  0.000000  ...       0.0   0.000000         1.0
# 19081  19357  0.000000  0.000000  ...       0.0   0.000000         1.0
# 19082  19359  0.000000  0.000000  ...       0.0   0.000000         1.0
# 19083  19360  0.000000  0.000000  ...       0.0   0.000000         1.0
# 19084  19364  0.000000  0.000000  ...       0.0   0.019231         1.0
#
# [19085 rows x 91 columns]

# %%
# testlist = list(range(1,19))
# c_li = col_standard

# testList = []
# for col in col_standard:
#   for h in testlist:
#     testList.append(f'{col}_{h}')

testList=['고객번호','내구재_r_1',
 '내구재_r_2',
 '내구재_r_3',
 '내구재_r_4',
 '내구재_r_5',
 '내구재_r_6',
 '내구재_r_7',
 '내구재_r_8',
 '내구재_r_9',
 '내구재_r_10',
 '내구재_r_11',
 '내구재_r_12',
 '내구재_r_13',
 '내구재_r_14',
 '내구재_r_15',
 '내구재_r_16',
 '내구재_r_17',
 '내구재_r_18',
  '준내구재_r_1',
 '준내구재_r_2',
 '준내구재_r_3',
 '준내구재_r_4',
 '준내구재_r_5',
 '준내구재_r_6',
 '준내구재_r_7',
 '준내구재_r_8',
 '준내구재_r_9',
 '준내구재_r_10',
 '준내구재_r_11',
 '준내구재_r_12',
 '준내구재_r_13',
 '준내구재_r_14',
 '준내구재_r_15',
 '준내구재_r_16',
 '준내구재_r_17',
 '준내구재_r_18',
 '비내구재_r_1',
 '비내구재_r_2',
 '비내구재_r_3',
 '비내구재_r_4',
 '비내구재_r_5',
 '비내구재_r_6',
 '비내구재_r_7',
 '비내구재_r_8',
 '비내구재_r_9',
 '비내구재_r_10',
 '비내구재_r_11',
 '비내구재_r_12',
 '비내구재_r_13',
 '비내구재_r_14',
 '비내구재_r_15',
 '비내구재_r_16',
 '비내구재_r_17',
 '비내구재_r_18',
 '사치품_r_1',
 '사치품_r_2',
 '사치품_r_3',
 '사치품_r_4',
 '사치품_r_5',
 '사치품_r_6',
 '사치품_r_7',
 '사치품_r_8',
 '사치품_r_9',
 '사치품_r_10',
 '사치품_r_11',
 '사치품_r_12',
 '사치품_r_13',
 '사치품_r_14',
 '사치품_r_15',
 '사치품_r_16',
 '사치품_r_17',
 '사치품_r_18',
]
test = test[testList]
test
# Out:
#         고객번호   내구재_r_1   내구재_r_2  ...  사치품_r_16  사치품_r_17  사치품_r_18
# 0          1  0.000000  0.000000  ...       0.0       0.0       0.0
# 1          2  0.055556  0.040816  ...       0.0       0.0       0.0
# 2          3  0.000000  0.000000  ...       0.0       0.0       0.0
# 3          4  0.000000  0.000000  ...       0.0       0.0       0.0
# 4          5  0.000000  0.000000  ...       0.0       0.0       0.0
# ...      ...       ...       ...  ...       ...       ...       ...
# 19080  19356  0.000000  0.000000  ...       0.0       0.0       0.0
# 19081  19357  0.000000  0.000000  ...       0.0       0.0       0.0
# 19082  19359  0.000000  0.000000  ...       0.0       0.0       0.0
# 19083  19360  0.000000  0.000000  ...       0.0       0.0       0.0
# 19084  19364  0.000000  0.000000  ...       0.0       0.0       0.0
#
# [19085 rows x 73 columns]

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/월별/test/m_new_ratio.pkl','wb') as test_save:
  pickle.dump(test,test_save)

# %%
with open('/content/drive/MyDrive/공유문서/1차 프로젝트/5조/1012발표도못하고수정/월별/test/m_new_ratio.pkl','rb') as test_save:
  check = pickle.load(test_save)

check
# Out:
#         고객번호   내구재_r_1   내구재_r_2  ...  사치품_r_16  사치품_r_17  사치품_r_18
# 0          1  0.000000  0.000000  ...       0.0       0.0       0.0
# 1          2  0.055556  0.040816  ...       0.0       0.0       0.0
# 2          3  0.000000  0.000000  ...       0.0       0.0       0.0
# 3          4  0.000000  0.000000  ...       0.0       0.0       0.0
# 4          5  0.000000  0.000000  ...       0.0       0.0       0.0
# ...      ...       ...       ...  ...       ...       ...       ...
# 19080  19356  0.000000  0.000000  ...       0.0       0.0       0.0
# 19081  19357  0.000000  0.000000  ...       0.0       0.0       0.0
# 19082  19359  0.000000  0.000000  ...       0.0       0.0       0.0
# 19083  19360  0.000000  0.000000  ...       0.0       0.0       0.0
# 19084  19364  0.000000  0.000000  ...       0.0       0.0       0.0
#
# [19085 rows x 73 columns]
